# %% [markdown]
# Introduction to Functions

# %% [markdown]
# They allow us to create blocks of code that can be easily executed many times, without needing to constantly rewrite the entire blocks of code

# %% [markdown]
# def Keyword

# %%
#Syntax
# def name_of_function(): (snake casing)
    # '''
    #     Docstring explains function.
    # '''
    # print('Hello')

# %%
#Function Call
    #name_of_function()

# %%
#arguments
# def name_of_function(name): (snake casing)
    # '''
    #     Docstring explains function.
    # '''
    # print('Hello'+name)
#Function Call
    #name_of_function('Khushi')

# %%
# return keyword to send back the result of the function
# return allows us to assign the output of function to new variable

# %%
def add_function(num1,num2):
    return num1+num2

# %%
result = add_function(1,2)
print(result)
# Out:
# 3
