# %%
# Question 1 (Variables)
# Create variables:
# Name = Khushi
# Age = 20
# Dream Job = Data Analyst
# Print them in a nice sentence.
Name = 'Khushi'
Age = 20
Dream_Job = 'Data Analyst'

# %%
print(f"My name is {Name}. I am {Age} years old and I want to become a {Dream_Job}.")
# Out:
# My name is Khushi. I am 20 years old and I want to become a Data Analyst.

# %%
#  Question 2 (Numbers)

# Take two numbers.

# Print:

# Addition
# Subtraction
# Multiplication
# Division

# %%
2+3
# Out:
# 5

# %%
2*3
# Out:
# 6

# %%
2-3
# Out:
# -1

# %%
2/3
# Out:
# 0.6666666666666666

# %%
# Question 3 (Strings)
# Given:
# sentence = "i will become a data analyst"
# Do this:
# Convert to uppercase
# Convert to title case
# Count how many letters "a" appear
# Replace "data analyst" with "Data Analyst at Microsoft"

sentence = "i will become a data analyst"

# %%
sentence.upper()
# Out:
# 'I WILL BECOME A DATA ANALYST'

# %%
sentence.title()
# Out:
# 'I Will Become A Data Analyst'

# %%
sentence.count('a')
# Out:
# 5

# %%
new_sentence = sentence.replace('data analyst', 'Data Analyst at Microsoft')

# %%
print(new_sentence)
# Out:
# i will become a Data Analyst at Microsoft

# %%
# Question 4 (Lists)
# Create a list of your 5 favourite foods.
# Then:
# Print first item
# Print last item
# Add one food
# Remove one food
# Print final list
my_list = ['mango','apple','banana','grapes','watermelon']

# %%
print(my_list[0])
# Out:
# mango

# %%
print(my_list[-1])
# Out:
# watermelon

# %%
my_list.append('dragonfruit')

# %%
my_list
# Out:
# ['mango', 'apple', 'banana', 'grapes', 'watermelon', 'dragonfruit']

# %%
my_list.pop(1)
# Out:
# 'apple'

# %%
print(my_list)
# Out:
# ['mango', 'banana', 'grapes', 'watermelon', 'dragonfruit']

# %%
# Question 5 (Dictionary)
# Make a dictionary:
# {
# "name": "...",
# "college": "...",
# "goal": "...",
# "city": "..."
# }

# Print each value separately

d={
"name": "Khushi",
"college": "Dtc",
"goal": "Data Analyst",
"city": "Delhi"
}

# %%
print(d["name"])
# Out:
# Khushi

# %%
print(d["college"])
# Out:
# Dtc

# %%
print(d["goal"])
# Out:
# Data Analyst

# %%
print(d["city"])
# Out:
# Delhi

# %%
# Question 6 (Tuple)
# Create a tuple containing
# your birthday
# birth month
# birth year
# Print it.

t=(24,12,2006)

# %%
print(t)
# Out:
# (24, 12, 2006)

# %%
# Question 7 (Set)
# Create a set:
# apple
# banana
# apple
# mango
# banana
# Print it.
# Notice what happens.

my_set= {'apple', 'banana', 'apple', 'mango', 'banana'}

# %%
print(my_set)
# Out:
# {'apple', 'banana', 'mango'}

# %%
# Question 8 (Booleans)
# Create
# 5 > 10
# 100 == 100
# 50 != 20
# Print each result.

result1 = 5 > 10

# %%
result2= 100 == 100

# %%
result3 = 50 != 20

# %%
print(result1 , result2, result3)
# Out:
# False True True

# %%
# Question 9 (Input)
# Ask the user:
# Name
# Favourite movie
# Then print
# Hi name, your favourite movie is ....
    
name = input('name')
fav_movie = input('favourite movie')
# Out:
# name Khushi
# favourite movie Om Shaanti Om

# %%
print(f'Hi {name}. Your favourite movie is {fav_movie}.')
# Out:
# Hi Khushi. Your favourite movie is Om Shaanti Om.

# %%
# Question 10
# Write a program that asks
# Enter your first name:
# Enter your last name:
# Then prints
# Welcome first_name last_name!
# using f-strings.

first_name= input('Enter your first name')
last_name= input('Enter your last name')
print(f'Welcome {first_name} {last_name}!')
# Out:
# Enter your first name Khushi
# Enter your last name Gupta
# Welcome Khushi Gupta
